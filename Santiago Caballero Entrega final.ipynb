# %% [markdown]
# # Entrega final
#
# **(Se requiere el notebook "Análisis de sueldos" resuelto)**

# %% [markdown]
# En base a los resultados obtenidos en *"Análisis de sueldos"* confeccionar conclusiones respecto a:
#
# - Rol vs sueldos
# - Nivel de educación alcanzada vs sueldos
# - Género vs sueldos
# - Tecnologías populares

# %% [markdown]
# Generar gráficos de barra para mostrar los resultados mencionados anteriormente usando strings, ej:
#
# ```
# developer | -----------------------------------------------
# sysadmin  | ---------------------------
# QA        | ------------------
#           | -----------------5%--------10%----------------40%
# ```

# %%
print('ROL VS SUELDOS')

print('''
De los datos analizados se puede visualizar que existe correlación entre 
el tipo de rol y el salario recibido.
''')

print('''
MEDIANA DEL SALARIO POR ROL(USD miles):
''')

print('BI Analyst / Data Analyst - |' + '-'*int(35.0))
print('Architect                 - |' + '-'*int(35.0))
print('HelpDesk                  - |' + '-'*int(29.0))
print('Consultant                - |' + '-'*int(29.8))
print('Data Engineer             - |' + '-'*int(29.8))
print('SUELDO EN USD MILES       - |'+'-'*9+'1'+'-'*9+'2'+'-'*9+'3'+'-'*9+'4')

print('''
NIVEL DE EDUCACIÓN ALCANZADA VS SUELDOS (USD miles):
''')

print('''
En la literatura existe una correlación positiva entre nivel de educación y sueldos. 
Esto se refleja en la encuesta siendo los niveles más altos de educación los que perciben sueldo más altos.
''')

print('Universitario Incompleto - |' + '-'*int(71.2))
print('Terciario En curso       - |' + '-'*int(26.0))
print('Posgrado En curso        - |' + '-'*int(24.5))
print('Universitario Completado - |' + '-'*int(24.5))
print('Posdoctorado En curso    - |' + '-'*int(24.5))
print('SUELDO EN USD MILES      - |'+'-'*9+'1'+'-'*9+'2'+'-'*9+'3'+'-'*9+'4'+'-'*9+'5'+'-'*9+'6'+'-'*9+'7'+'-'*5)

print('''
GENERO VS SUELDOS (USD miles):
''')
print('''
La evidencia empirica internacional muestra como el genero influye en el sueldo, 
dado que a iguales condiciones, los hombres ganan más que las mujeres.
Esta hipotesis no se puede confirmar en la muestra analizada ya que ambos géneros presentan
el mismo nivel de sueldos.
''')

print('Varón Cis                - |' + '-'*int(24.5))
print('Mujer Cis                - |' + '-'*int(24.5))
print('SUELDO EN USD MILES      - |'+'-'*9+'1'+'-'*9+'2'+'-'*9+'3')

print('''
TECONOLOGIAS POPULARES
''')

print('''
La tecnologias van mudando permantente, y las preferencias por las mismas tambien.
Asimismo la constante aparición de nuevas tecnologías hace que los resultados que se puedan obtener hoy ya no tengan relevancia unos pocos meses mas adelante.
En este marco, se presentan a continuación las tecnologías que perciben un mejor salario en la base analizada.
''')

print ('''
PLATAFORMAS (USD miles):
''')
print('Azure, Docker, Kubernetes, Linux, SAP           - |' + '-'*int(23.0))
print('Docker, Kubernetes, Linux, VMWare, Rancher      - |' + '-'*int(23.0))
print('Google Cloud Platform/App Engine, Linux, VMWare - |' + '-'*int(23.0))
print('Amazon Web Services, *BSD, Heroku               - |' + '-'*int(23.0))
print('Docker, Firebase, Linux, OpenShift              - |' + '-'*int(23.0))
print('SUELDO EN USD MILES                             - |'+'-'*9+'1'+'-'*9+'2'+'-'*9+'3')

print('''
FRAMEWORK, HERRAMIENTAS Y LIBRERIAS (USD miles):
''')
print('Bootstrap, CodeIgniter, Cordova, Drupal, jQuery, WordPress- |' + '-'*int(24.0))
print('Angular, Bootstrap, Flask, jQuery, Node.js, React.js      - |' + '-'*int(24.0))
print('Torch, pandas, numpy, scipy                               - |' + '-'*int(24.0))
print('Django, Spring                                            - |' + '-'*int(24.0))
print('Flutter, Rails, React.js                                  - |' + '-'*int(24.0))
print('SUELDO EN USD MILES                                       - |'+'-'*9+'1'+'-'*9+'2'+'-'*9+'3')
print('''
BASES DE DATOS (USD miles):
''')
print('Oracle, Sybase                                                      - |' + '-'*int(26.0))
print('Cassandra, Microsoft SQL Server, MySQL, SQLite                      - |' + '-'*int(26.0))
print('Amazon: DynamoDB, Redshift, Google Cloud Storage, Microsoft Azure   - |' + '-'*int(26.0))
print('Microsoft SQL Server, Oracle, PostgreSQL                            - |' + '-'*int(26.0))
print('MySQL, Oracle, Teradata                                             - |' + '-'*int(26.0))
print('SUELDO EN USD MILES                                                 - |'+'-'*9+'1'+'-'*9+'2'+'-'*9+'3')
print('''
QA / TESTING (USD miles):
''')
print('Cucumber, Karma, Mocha, NUnit, Postman, Selenium, SoapUI, TFS - |' + '-'*int(38.0))
print('Katalon, Postman, Selenium                                    - |' + '-'*int(38.0))
print('Appium, Cucumber, Postman, RSpec, Selenium                    - |' + '-'*int(33.0))
print('Karma, NUnit, Postman                                         - |' + '-'*int(33.0))
print('jmeter                                                        - |' + '-'*int(33.0))
print('SUELDO EN USD MILES                                           - |'+'-'*9+'1'+'-'*9+'2'+'-'*9+'3'+'-'*9+'4')
print('''
IDEs
''')
print('Notepad++, Sublime Text, Xcode                                     - |' + '-'*int(24.0))
print('PHPStorm, Sublime Text, Vi, Vim, Visual Studio, Visual Studio Code - |' + '-'*int(23.9))
print('Android Studio, IntelliJ, Vim, Visual Studio Code, Xcode           - |' + '-'*int(23.9))
print('Nano, Wing Pro 7.2, Gedit                                          - |' + '-'*int(23.9))
print('NetBeans, PyCharm, Visual Studio Code                              - |' + '-'*int(23.9))
print('SUELDO EN USD MILES                                                - |'+'-'*9+'1'+'-'*9+'2'+'-'*9+'3')
